# %%
import pandas as pd

# %%
df = pd.read_csv('data/WT-2023-M.csv')

# %%
df
# Out:
#                                                      @id  \
# 0      http://environment.data.gov.uk/water-quality/d...
# 1      http://environment.data.gov.uk/water-quality/d...
# 2      http://environment.data.gov.uk/water-quality/d...
# 3      http://environment.data.gov.uk/water-quality/d...
# 4      http://environment.data.gov.uk/water-quality/d...
# ...                                                  ...
# 41117  http://environment.data.gov.uk/water-quality/d...
# 41118  http://environment.data.gov.uk/water-quality/d...
# 41119  http://environment.data.gov.uk/water-quality/d...
# 41120  http://environment.data.gov.uk/water-quality/d...
# 41121  http://environment.data.gov.uk/water-quality/d...
#
#                                     sample.samplingPoint  \
# 0      http://environment.data.gov.uk/water-quality/i...
# 1      http://environment.data.gov.uk/water-quality/i...
# 2      http://environment.data.gov.uk/water-quality/i...
# ...

# %%
df.head(10)
# Out:
#                                                  @id  \
# 0  http://environment.data.gov.uk/water-quality/d...
# 1  http://environment.data.gov.uk/water-quality/d...
# 2  http://environment.data.gov.uk/water-quality/d...
# 3  http://environment.data.gov.uk/water-quality/d...
# 4  http://environment.data.gov.uk/water-quality/d...
# 5  http://environment.data.gov.uk/water-quality/d...
# 6  http://environment.data.gov.uk/water-quality/d...
# 7  http://environment.data.gov.uk/water-quality/d...
# 8  http://environment.data.gov.uk/water-quality/d...
# 9  http://environment.data.gov.uk/water-quality/d...
#
#                                 sample.samplingPoint  \
# 0  http://environment.data.gov.uk/water-quality/i...
# 1  http://environment.data.gov.uk/water-quality/i...
# 2  http://environment.data.gov.uk/water-quality/i...
# 3  http://environment.data.gov.uk/water-quality/i...
# 4  http://environment.data.gov.uk/water-quality/i...
# 5  http://environment.data.gov.uk/water-quality/i...
# ...

# %%
df[df['sample.samplingPoint.label'] == 'U/S FENNY COMPTON ROAD']
# Out:
#                                                      @id  \
# 41034  http://environment.data.gov.uk/water-quality/d...
# 41035  http://environment.data.gov.uk/water-quality/d...
# 41036  http://environment.data.gov.uk/water-quality/d...
# 41037  http://environment.data.gov.uk/water-quality/d...
# 41038  http://environment.data.gov.uk/water-quality/d...
# ...                                                  ...
# 41117  http://environment.data.gov.uk/water-quality/d...
# 41118  http://environment.data.gov.uk/water-quality/d...
# 41119  http://environment.data.gov.uk/water-quality/d...
# 41120  http://environment.data.gov.uk/water-quality/d...
# 41121  http://environment.data.gov.uk/water-quality/d...
#
#                                     sample.samplingPoint  \
# 41034  http://environment.data.gov.uk/water-quality/i...
# 41035  http://environment.data.gov.uk/water-quality/i...
# 41036  http://environment.data.gov.uk/water-quality/i...
# ...

# %%
list(set(df['sample.samplingPoint.notation']))
# Out:
# ['TH-PKER0003',
#  'TH-PRTS0035',
#  'TH-PWER0007',
#  'TH-PUTR0069',
#  'TH-PRTS0063',
#  'TH-PLDR0054',
#  'TH-PEVR0003',
#  'TH-PLDR0034',
#  'TH-PTAR0038',
#  'TH-PUTR0081',
#  'TH-RSN0978',
#  'TH-PWER0026',
#  'TH-PPSR0007',
#  'TH-PLDR0029',
#  'TH-PGWU1996',
#  'TH-PGWU2017',
#  'TH-RSN2130',
#  'TH-PRTS0060',
#  'TH-PRTS0038',
#  'TH-POCR0013',
#  'TH-PTAR0034',
#  'TH-PGWU0662',
#  'TH-PWEE9999',
#  'TH-PRTS0127',
#  'TH-PTAR0065',
#  'TH-RSN0114',
#  'TH-PRTS0040',
#  'TH-PGWU2042',
#  'TH-PWRR0021',
#  'TH-PEVR0011',
#  'TH-RSN0930',
#  'TH-PEVR0006',
#  'TH-PCHR0055',
#  'TH-RSN1850',
#  'TH-PWER0023',
#  'TH-PGWU1615',
#  'TH-POCR0016',
#  'TH-PPSR0003',
#  'TH-PGWU1918',
#  'TH-PRTS0131',
#  'TH-PGWL0188',
#  'TH-PUTR0061',
#  'TH-PGWU0986',
#  'TH-PGWU2073',
#  'TH-PWER0033',
#  'TH-PRTS0124',
#  'TH-PUTR0097',
#  'TH-PWER0104',
#  'TH-PRTS0043',
#  'TH-POCR9999',
#  'TH-PRTS0058',
#  'TH-PTAR0033',
#  'TH-RSN0226',
#  'TH-SSN0507',
#  'TH-PTHR0105',
# ...
